# %%
from pathlib import Path
import matplotlib.pyplot as plt
import panel as pn
from axis_finder.app import App as AxisFinder

pn.extension()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='5e2bf6de-a560-43cb-ac07-319174bc2ff6'>
#   <div id="f5cf0ac0-7dd1-4a2e-9580-e292d151e60f" data-root-id="5e2bf6de-a560-43cb-ac07-319174bc2ff6" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
app = AxisFinder(Path("/home/koe/Documents/University/Mathematics/Seminar Tomography I/Repository/data/images/dolphin"))

# %%
app.make()
# Out:
# Row(margin=10)
#     [0] WidgetBox(width=500)
#         [0] Column(margin=10)
#             [0] Markdown(str)
#             [1] EditableRangeSlider(end=800, format=PrintfTickFormatter(id='28..., name='Image range', sizing_mode='stretch_width', start=1, step=1, value=(1, 400))
#             [2] Markdown(str)
#             [3] EditableIntSlider(end=400, name='Selected image index', sizing_mode='stretch_width', start=1, value=1)
#             [4] Markdown(str)
#             [5] Row
#                 [0] EditableIntSlider(end=4000, name='Center X', sizing_mode='stretch_width', value=2000)
#                 [1] EditableIntSlider(end=3000, name='Center Y', sizing_mode='stretch_width', value=1500)
#             [6] Row
#                 [0] EditableIntSlider(end=4000, name='Crop Width', sizing_mode='stretch_width', start=1, value=4000)
#                 [1] EditableIntSlider(end=3000, name='Crop Height', sizing_mode='stretch_width', start=1, value=3000)
#             [7] Spacer(height=10)
# ...

# %%
plt.imshow(app.get_grayscale_cropped_image(1))
